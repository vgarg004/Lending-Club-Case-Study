# %% [markdown]
#  # EDA for Lending Club Data

# %% [markdown]
#                                                                           Deployed By Vikas Garg and Chacko Mulackel

# %% [markdown]
# ### Description
#
# When the company receives a loan application, the company has to make a decision for loan approval based on the applicant’s profile. Two types of risks are associated with the bank’s decision:
# •	If the applicant is likely to repay the loan, then not approving the loan results in a loss of business to the company
# •	If the applicant is not likely to repay the loan, i.e. he/she is likely to default, then approving the loan may lead to a financial loss for the company
#
#
# ### About Data:
#
# The data given below contains the information about past loan applicants and whether they ‘defaulted’ or not. The aim is to identify patterns which indicate if a person is likely to default, which may be used for taking actions such as denying the loan, reducing the amount of loan, lending (to risky applicants) at a higher interest rate, etc.
#
# ### Objective:
#
# When a person applies for a loan, there are two types of decisions that could be taken by the company:
# 1.	Loan accepted: If the company approves the loan, there are 3 possible scenarios described below:
# o	Fully paid: Applicant has fully paid the loan (the principal and the interest rate)
# o	Current: Applicant is in the process of paying the instalments, i.e. the tenure of the loan is not yet completed. These candidates are not labelled as 'defaulted'.
# o	Charged-off: Applicant has not paid the instalments in due time for a long period of time, i.e. he/she has defaulted on the loan
# 2.	Loan rejected: The company had rejected the loan (because the candidate does not meet their requirements etc.). Since the loan was rejected, there is no transactional history of those applicants with the company and so this data is not available with the company (and thus in this dataset)
#
# This notebook finds consumer attributes and loan attributes influence the tendency of default.
#
# `The company wants to understand the driving factors (or driver variables) behind loan default, i.e. the variables which are strong indicators of default.  The company can utilise this knowledge for its portfolio and risk assessment.`

# %% [markdown]
# # 1. Data Sourcing

# %%
#Import required packages 

import numpy as np
import pandas as pd
import matplotlib.pyplot as plt
import seaborn as sns
import datetime
pd.set_option('display.float_format', lambda x: '%.2f' % x)
pd.set_option('display.max_rows',200)
pd.set_option('display.max_columns',200)
import warnings
warnings.filterwarnings('ignore')
from IPython.core.pylabtools import figsize

# %%
# Defining Source Path

#loan = "/mnt/c/Users/Jaimy/Documents/Data/Dataset/loan/loan.csv"

# %% [markdown]
# # Checking encoding of loan dataset
#
# import chardet
#
# with open(loan, 'rb') as f:
#     result = chardet.detect(f.readline())
#
# print(result)

# %%
df=pd.read_csv('loan.csv',engine='python')
#df =pd.read_csv(loan, engine = 'python')

# %%
df.shape
# Out:
# (39717, 111)

# %% [markdown]
# ###### The original data set contain 39717 observations and 111 variables

# %%
df.head(100)
# Out:
#          id  member_id  loan_amnt  funded_amnt  funded_amnt_inv        term  \
# 0   1077501    1296599       5000         5000          4975.00   36 months
# 1   1077430    1314167       2500         2500          2500.00   60 months
# 2   1077175    1313524       2400         2400          2400.00   36 months
# 3   1076863    1277178      10000        10000         10000.00   36 months
# 4   1075358    1311748       3000         3000          3000.00   60 months
# 5   1075269    1311441       5000         5000          5000.00   36 months
# 6   1069639    1304742       7000         7000          7000.00   60 months
# 7   1072053    1288686       3000         3000          3000.00   36 months
# 8   1071795    1306957       5600         5600          5600.00   60 months
# 9   1071570    1306721       5375         5375          5350.00   60 months
# 10  1070078    1305201       6500         6500          6500.00   60 months
# 11  1069908    1305008      12000        12000         12000.00   36 months
# 12  1064687    1298717       9000         9000          9000.00   36 months
# 13  1069866    1304956       3000         3000          3000.00   36 months
# 14  1069057    1303503      10000        10000         10000.00   36 months
# 15  1069759    1304871       1000         1000          1000.00   36 months
# 16  1065775    1299699      10000        10000         10000.00   36 months
# 45    9.91%       451.15     B        B1
# 46    8.90%       158.77     A        A5
# 47   10.65%       325.74     B        B2
# 48    6.03%       304.36     A        A1
# 49    6.62%       337.75     A        A2
# 50    9.91%       483.38     B        B1
# 51    9.91%       824.96     B        B1
# 52   10.65%       228.02     B        B2
# 53   15.96%       421.65     C        C5
# 54    9.91%       386.70     B        B1
# 55   19.91%       555.33     E        E4
# 56   19.91%       423.11     E        E4
# 57   12.42%       334.16     B        B4
# 58   10.65%       325.74     B        B2
# 59   16.77%       252.33     D        D2
# 60   12.69%       293.74     B        B5
# 61   17.27%       223.74     D        D3
# 62   14.65%       417.25     C        C3
# 63   16.77%       284.31     D        D2
# 64   10.65%       215.69     B        B2
# 65   10.65%       114.01     B        B2
# 66   17.27%       223.11     D        D3
# 67   14.27%       563.53     C        C2
# 68   21.28%       223.14     F        F2
# 69   14.65%       517.42     C        C3
# 70   17.58%       341.63     D        D4
# 71   16.77%       227.45     D        D2
# 72   13.49%       101.80     C        C1
# 73   16.77%       426.47     D        D2
# 74    8.90%       457.25     A        A5
# 75   14.65%       413.94     C        C3
# 76   13.49%       373.24     C        C1
# 77   21.67%       197.51     F        F3
# 78    7.90%       469.36     A        A4
# 79   19.91%       475.99     E        E4
# 80   17.27%       551.84     D        D3
# 81   14.27%       343.09     C        C2
# 82   12.69%       395.83     B        B5
# 83    6.03%       136.96     A        A1
# 84   12.69%       234.82     B        B5
# 85   12.42%       307.43     B        B4
# 86   17.27%       349.98     D        D3
# 87   10.65%        97.06     B        B2
# 88   16.29%       423.61     D        D1
# 89   13.49%       407.17     C        C1
# 90   10.65%       390.88     B        B2
# 91   10.65%       228.02     B        B2
# 92   19.42%       214.62     E        E3
# 93   12.69%       352.23     B        B5
# 94   11.71%       231.54     B        B3
# 95   22.06%       423.10     F        F4
# 96   11.71%       282.86     B        B3
# 97   17.27%       437.47     D        D3
# 98    6.03%       106.53     A        A1
# 99   12.69%       135.57     B        B5
#
#                                    emp_title emp_length home_ownership  \
# 0                                        NaN  10+ years           RENT
# 1                                      Ryder   < 1 year           RENT
# 2                                        NaN  10+ years           RENT
# 3                        AIR RESOURCES BOARD  10+ years           RENT
# 4                   University Medical Group     1 year           RENT
# 5                       Veolia Transportaton    3 years           RENT
# 6                  Southern Star Photography    8 years           RENT
# 7                            MKC Accounting     9 years           RENT
# 8                                        NaN    4 years            OWN
# 9                                  Starbucks   < 1 year           RENT
# 10                     Southwest Rural metro    5 years            OWN
# 11                                      UCLA  10+ years            OWN
# 12       Va. Dept of Conservation/Recreation   < 1 year           RENT
# 13                                    Target    3 years           RENT
# 14                                     SFMTA    3 years           RENT
# 15                  Internal revenue Service   < 1 year           RENT
# 16                         Chin's Restaurant    4 years           RENT
# 17                                  Duracell  10+ years       MORTGAGE
# 18                     Connection Inspection     1 year       MORTGAGE
# 19              Network Interpreting Service    6 years           RENT
# 20          Archdiocese of Galveston Houston    3 years           RENT
# 21                            Osram Sylvania  10+ years           RENT
# 22                                 Value Air  10+ years            OWN
# 23                          Wells Fargo Bank    5 years           RENT
# 24                           bmg-educational     1 year           RENT
# 25            Winfield Pathology Consultants    2 years       MORTGAGE
# 26                               nyc transit    9 years           RENT
# 27                                 Frito Lay    2 years           RENT
# 28   Shands Hospital at the University of Fl  10+ years       MORTGAGE
# 29                            Oakridge homes   < 1 year           RENT
# 30                                       NaN    7 years       MORTGAGE
# 31        Audubon Mutual Housing Corporation    5 years       MORTGAGE
# 32                          US Legal Support    2 years           RENT
# 33                    Good Samaritan Society    2 years           RENT
# 34                      GREG BARRETT DRYWALL    7 years           RENT
# 35                           Sharp Lawn Inc.  10+ years           RENT
# 36                     Department of Justice    2 years           RENT
# 37                           Gateway Hospice     1 year           RENT
# 38                        Cox Communications     1 year           RENT
# 39  United States Infrastructure Corporation     1 year           RENT
# 40                    Nucor Building Systems    4 years           RENT
# 41                            John Wiley Jr.  10+ years           RENT
# 42                                       NaN    9 years       MORTGAGE
# 43                             citizens bank  10+ years           RENT
# 44                 Stewart Enterprises, Inc.  10+ years       MORTGAGE
# 45                         golfers warehouse    6 years           RENT
# 46                        STERIS Corporation  10+ years       MORTGAGE
# 47                    Costco Wholesale Corp.    6 years           RENT
# 48                                  Helicoil  10+ years           RENT
# 49            cognizant technology solutions    5 years           RENT
# 50                          Caterpillar Inc.    8 years       MORTGAGE
# 51                     City of Santa Monica     9 years           RENT
# 52                        Aerotek Scientific   < 1 year           RENT
# 53                     Chemat Technology Inc    4 years           RENT
# 54                             Scott & White     1 year           RENT
# 55                                    Costco    7 years           RENT
# 56                           CA Technologies    7 years           RENT
# 57                                   Netflix   < 1 year            OWN
# 58                                      DCAA    2 years           RENT
# 59                        Triple D security      1 year       MORTGAGE
# 60                                    wrisco   < 1 year       MORTGAGE
# 61                                       NaN    6 years           RENT
# 62                                webb candy   < 1 year           RENT
# 63                                 Omniplex    < 1 year           RENT
# 64                     CEC ENTERTAINMENT INC  10+ years           RENT
# 65                                       CPI    7 years       MORTGAGE
# 66                           grandma kitchen    5 years           RENT
# 67                            Gen-Probe, Inc    4 years           RENT
# 68                                  autozone    4 years           RENT
# 69                        USAF Civil Service    2 years            OWN
# 70                        Dollar Tree Stores    5 years       MORTGAGE
# 71              Riverside County, California    5 years           RENT
# 72                     Insight Card Services     1 year           RENT
# 73                       Genocea Biosciences    3 years           RENT
# 74                             Model Metrics   < 1 year            OWN
# 75                            Boro of Butler  10+ years           RENT
# 76                    TX Army National Guard  10+ years       MORTGAGE
# 77                 Cross Country Travel Corp   < 1 year           RENT
# 78               Segovia's Transportion Inc.     1 year       MORTGAGE
# 79                        AVMED HEALTH PLANS  10+ years       MORTGAGE
# 80                 tutor Per ini Corporation    3 years       MORTGAGE
# 81                                       SAP    2 years           RENT
# 82                            Koi Restaurant    6 years           RENT
# 83                                 CaseStack    4 years           RENT
# 84           Bellflower convalecent hospital  10+ years           RENT
# 85                         Kaiser Permanente    2 years           RENT
# 86             community colleges of spokane    4 years           RENT
# 87                       barnes distribution   < 1 year       MORTGAGE
# 88                   Phoenix Newspapers Inc.    9 years           RENT
# 89                             LITHIA MOTORS    4 years           RENT
# 90                            Insight Global   < 1 year           RENT
# 91                     Winghouse Corporation    3 years       MORTGAGE
# 92                           Claret Wine Bar    3 years           RENT
# 93                                  O'Connor  10+ years           RENT
# 94                                    Harris    4 years            OWN
# 95                                      OSSI    6 years           RENT
# 96                          NCS Technologies    4 years       MORTGAGE
# 97                       Travelers Insurance    7 years       MORTGAGE
# 98                             J&J Steel Inc  10+ years       MORTGAGE
# 99            Anadarko Petroleum Corporation   < 1 year           RENT
#
#     annual_inc verification_status issue_d  loan_status pymnt_plan  \
# 0     24000.00            Verified  Dec-11   Fully Paid          n
# 1     30000.00     Source Verified  Dec-11  Charged Off          n
# 2     12252.00        Not Verified  Dec-11   Fully Paid          n
# 3     49200.00     Source Verified  Dec-11   Fully Paid          n
# 4     80000.00     Source Verified  Dec-11      Current          n
# 5     36000.00     Source Verified  Dec-11   Fully Paid          n
# 6     47004.00        Not Verified  Dec-11   Fully Paid          n
# 7     48000.00     Source Verified  Dec-11   Fully Paid          n
# 8     40000.00     Source Verified  Dec-11  Charged Off          n
# 9     15000.00            Verified  Dec-11  Charged Off          n
# 10    72000.00        Not Verified  Dec-11   Fully Paid          n
# 11    75000.00     Source Verified  Dec-11   Fully Paid          n
# 12    30000.00     Source Verified  Dec-11  Charged Off          n
# 13    15000.00     Source Verified  Dec-11   Fully Paid          n
# 14   100000.00     Source Verified  Dec-11  Charged Off          n
# 15    28000.00        Not Verified  Dec-11   Fully Paid          n
# 16    42000.00        Not Verified  Dec-11   Fully Paid          n
# 17   110000.00        Not Verified  Dec-11   Fully Paid          n
# 18    84000.00            Verified  Dec-11   Fully Paid          n
# 19    77385.19        Not Verified  Dec-11   Fully Paid          n
# 20    43370.00            Verified  Dec-11   Fully Paid          n
# 21   105000.00            Verified  Dec-11  Charged Off          n
# 22    50000.00     Source Verified  Dec-11   Fully Paid          n
# 23    50000.00        Not Verified  Dec-11   Fully Paid          n
# 24    76000.00        Not Verified  Dec-11  Charged Off          n
# 25    92000.00            Verified  Dec-11   Fully Paid          n
# 26    60000.00        Not Verified  Dec-11  Charged Off          n
# 27    50004.00        Not Verified  Dec-11  Charged Off          n
# 28   106000.00        Not Verified  Dec-11   Fully Paid          n
# 29    25000.00     Source Verified  Dec-11   Fully Paid          n
# 30    17108.00     Source Verified  Dec-11   Fully Paid          n
# 31    75000.00            Verified  Dec-11   Fully Paid          n
# 32    29120.00            Verified  Dec-11      Current          n
# 33    24044.00            Verified  Dec-11   Fully Paid          n
# 34    34000.00     Source Verified  Dec-11   Fully Paid          n
# 35    41000.00        Not Verified  Dec-11   Fully Paid          n
# 36    55596.00     Source Verified  Dec-11   Fully Paid          n
# 37    45000.00            Verified  Dec-11   Fully Paid          n
# 38    36852.00     Source Verified  Dec-11   Fully Paid          n
# 39    27000.00            Verified  Dec-11      Current          n
# 40    68004.00     Source Verified  Dec-11   Fully Paid          n
# 41    62300.00        Not Verified  Dec-11   Fully Paid          n
# 42    65000.00        Not Verified  Dec-11   Fully Paid          n
# 43    55000.00        Not Verified  Dec-11   Fully Paid          n
# 44    45600.00        Not Verified  Dec-11   Fully Paid          n
# 45    80000.00        Not Verified  Dec-11   Fully Paid          n
# 46   100000.00     Source Verified  Dec-11  Charged Off          n
# 47    27000.00            Verified  Dec-11   Fully Paid          n
# 48    60000.00        Not Verified  Dec-11   Fully Paid          n
# 49    70000.00        Not Verified  Dec-11   Fully Paid          n
# 50    80000.00        Not Verified  Dec-11  Charged Off          n
# 51   110000.00            Verified  Dec-11   Fully Paid          n
# 52    40000.00        Not Verified  Dec-11   Fully Paid          n
# 53    50000.00        Not Verified  Dec-11  Charged Off          n
# 54    46000.00        Not Verified  Dec-11   Fully Paid          n
# 55    50000.00            Verified  Dec-11  Charged Off          n
# 56    81000.00            Verified  Dec-11   Fully Paid          n
# 57    39000.00        Not Verified  Dec-11   Fully Paid          n
# 58    51400.00        Not Verified  Dec-11   Fully Paid          n
# 59    33000.00            Verified  Dec-11   Fully Paid          n
# 60    30000.00     Source Verified  Dec-11   Fully Paid          n
# 61    40000.00            Verified  Dec-11   Fully Paid          n
# 62    50000.00     Source Verified  Dec-11   Fully Paid          n
# 63    62000.00        Not Verified  Dec-11   Fully Paid          n
# 64    45996.00            Verified  Dec-11  Charged Off          n
# 65    55000.00        Not Verified  Dec-11   Fully Paid          n
# 66    30000.00     Source Verified  Dec-11  Charged Off          n
# 67    44544.00     Source Verified  Dec-11   Fully Paid          n
# 68    75000.00     Source Verified  Dec-11  Charged Off          n
# 69    61000.00            Verified  Dec-11   Fully Paid          n
# 70    44000.00            Verified  Dec-11   Fully Paid          n
# 71    75000.00        Not Verified  Dec-11  Charged Off          n
# 72    33600.00        Not Verified  Dec-11   Fully Paid          n
# 73    50000.00        Not Verified  Dec-11   Fully Paid          n
# 74   150000.00     Source Verified  Dec-11   Fully Paid          n
# 75    90000.00        Not Verified  Dec-11   Fully Paid          n
# 76    48000.00            Verified  Dec-11   Fully Paid          n
# 77    75000.00            Verified  Dec-11   Fully Paid          n
# 78    52000.00        Not Verified  Dec-11   Fully Paid          n
# 79    65000.00        Not Verified  Dec-11   Fully Paid          n
# 80   150000.00            Verified  Dec-11   Fully Paid          n
# 81    68000.00     Source Verified  Dec-11   Fully Paid          n
# 82    42000.00     Source Verified  Dec-11   Fully Paid          n
# 83    53000.00     Source Verified  Dec-11   Fully Paid          n
# 84    35000.00     Source Verified  Dec-11   Fully Paid          n
# 85    60000.00     Source Verified  Dec-11   Fully Paid          n
# 86    28000.00            Verified  Dec-11      Current          n
# 87    42000.00     Source Verified  Dec-11   Fully Paid          n
# 88    88365.00            Verified  Dec-11   Fully Paid          n
# 89    72000.00     Source Verified  Dec-11   Fully Paid          n
# 90    62000.00            Verified  Dec-11   Fully Paid          n
# 91    43680.00        Not Verified  Dec-11   Fully Paid          n
# 92   120000.00     Source Verified  Dec-11   Fully Paid          n
# 93    66000.00            Verified  Dec-11   Fully Paid          n
# 94    39120.00        Not Verified  Dec-11   Fully Paid          n
# 95    85000.00            Verified  Dec-11      Current          n
# 10    Borrower added on 12/15/11 > I had recived a...  debt_consolidation
# 11                                                NaN  debt_consolidation
# 12    Borrower added on 12/15/11 > Plan to pay off...  debt_consolidation
# 13    Borrower added on 12/19/11 > I intend to pay...         credit_card
# 14                                                NaN               other
# 15                                                NaN  debt_consolidation
# 16                                                NaN    home_improvement
# 17    Borrower added on 12/15/11 > Payoff other le...      major_purchase
# 18    Borrower added on 12/16/11 > This is a loan ...             medical
# 19                                                NaN  debt_consolidation
# 20  After amassing credit card debt through severa...  debt_consolidation
# 21    Borrower added on 12/16/11 > Decided to clea...  debt_consolidation
# 22    Borrower added on 12/17/11 > Have a stable j...         credit_card
# 23                                                NaN  debt_consolidation
# 24                                                NaN      major_purchase
# 25                                                NaN         credit_card
# 26    Borrower added on 12/15/11 > looking to cons...  debt_consolidation
# 27    Borrower added on 12/16/11 > I have a stable...               other
# 28                                                NaN  debt_consolidation
# 29    Borrower added on 12/15/11 > My loan is for ...         credit_card
# 30    Borrower added on 12/17/11 > This loan is a ...  debt_consolidation
# 31    Borrower added on 12/15/11 > Hello<br>I plan...  debt_consolidation
# 32                                                NaN  debt_consolidation
# 33    Borrower added on 12/16/11 > The purpose of ...  debt_consolidation
# 34                                                NaN         credit_card
# 35    Borrower added on 12/16/11 > I plan to use t...         credit_card
# 36    Borrower added on 12/19/11 > I have a very s...              moving
# 37    Borrower added on 12/15/11 > I am looking to...  debt_consolidation
# 38    Borrower added on 12/15/11 > This loan will ...  debt_consolidation
# 39    Borrower added on 12/20/11 > The purpose of ...  debt_consolidation
# 40    Borrower added on 12/15/11 > Funds will be u...               other
# 41    Borrower added on 12/15/11 > To be used to p...  debt_consolidation
# 42    Borrower added on 12/15/11 > Combination of ...               other
# 43                                                NaN  debt_consolidation
# 44    Borrower added on 12/16/11 > Debt Consolidat...  debt_consolidation
# 45    Borrower added on 12/15/11 > i am opening a ...      small_business
# 46                                                NaN  debt_consolidation
# 47                                                NaN               other
# 48                                                NaN         credit_card
# 49                                                NaN  debt_consolidation
# 50    Borrower added on 12/15/11 > Using to pay of...  debt_consolidation
# 51    Borrower added on 12/14/11 > I would like to...         credit_card
# 52                                                NaN  debt_consolidation
# 53                                                NaN                 car
# 54    Borrower added on 12/19/11 > I got crazy wit...         credit_card
# 55    Borrower added on 12/20/11 > consolidation  ...  debt_consolidation
# 56    Borrower added on 12/16/11 > Will use this o...         credit_card
# 57                                                NaN  debt_consolidation
# 58    Borrower added on 12/21/11 > I plan to use t...         credit_card
# 59   I wna apply for $7100 loan to pay off all cre...  debt_consolidation
# 60    Borrower added on 12/07/11 > plan to use the...  debt_consolidation
# 61    Borrower added on 11/28/11 > Thanks.<br> Bor...      small_business
# 62    Borrower added on 12/07/11 > I am trying to ...  debt_consolidation
# 63    Borrower added on 12/16/11 > I am looking to...  debt_consolidation
# 64                                                NaN  debt_consolidation
# 65    Borrower added on 12/15/11 > pay off credit ...  debt_consolidation
# 66    Borrower added on 12/16/11 > So I can pay al...  debt_consolidation
# 67    Borrower added on 12/14/11 > looking to find...  debt_consolidation
# 68    Borrower added on 12/15/11 > Business/credit...      small_business
# 69    Borrower added on 12/14/11 > I calculated re...         credit_card
# 70    Borrower added on 12/18/11 > We are looking ...         credit_card
# 71    Borrower added on 12/14/11 > Debt consolidat...  debt_consolidation
# 72                                                NaN  debt_consolidation
# 73    Borrower added on 12/14/11 > This loan is fo...         credit_card
# 74    Borrower added on 12/15/11 > I have some 0% ...  debt_consolidation
# 75                                                NaN  debt_consolidation
# 76                                                NaN  debt_consolidation
# 77  I have been steadily employed.  I am a hard wo...  debt_consolidation
# 78                                                NaN      small_business
# 79    Borrower added on 12/20/11 > I've been worki...  debt_consolidation
# 80                                                NaN    home_improvement
# 81    Borrower added on 12/14/11 > Consolidation o...         credit_card
# 82   Loan for refinancing credit cards and finishi...         credit_card
# 83                                                NaN      major_purchase
# 84     Borrower added on 12/14/11 > Pay my credit<br>         credit_card
# 85    Borrower added on 12/14/11 > Debt Consolidat...  debt_consolidation
# 86    Borrower added on 12/18/11 > most of my teet...               other
# 87    Borrower added on 12/20/11 > The loan is to ...                 car
# 88    Borrower added on 12/14/11 > looking to pay ...  debt_consolidation
# 89    Borrower added on 12/14/11 > I HAVE SOME CRE...  debt_consolidation
# 90    Borrower added on 12/15/11 > with fixed amou...         credit_card
# 91    Borrower added on 12/14/11 > I plan on payin...         credit_card
# 92                                                NaN  debt_consolidation
# 93    Borrower added on 12/21/11 > My job is  in t...             medical
# 94                                                NaN  debt_consolidation
# 95                                                NaN         credit_card
# 96                                                NaN  debt_consolidation
# 97    Borrower added on 12/14/11 > Pay off credit ...         credit_card
# 98    Borrower added on 12/14/11 > 1993 jeep wrang...                 car
# 99    Borrower added on 12/15/11 > The following i...      major_purchase
#
#                                     title zip_code addr_state   dti  \
# 0                                Computer    860xx         AZ 27.65
# 1                                    bike    309xx         GA  1.00
# 2                    real estate business    606xx         IL  8.72
# 3                                personel    917xx         CA 20.00
# 4                                Personal    972xx         OR 17.94
# 5   My wedding loan I promise to pay back    852xx         AZ 11.20
# 6                                    Loan    280xx         NC 23.51
# 7                         Car Downpayment    900xx         CA  5.35
# 8    Expand Business & Buy Debt Portfolio    958xx         CA  5.55
# 9             Building my credit history.    774xx         TX 18.08
# 10             High intrest Consolidation    853xx         AZ 16.12
# 11                          Consolidation    913xx         CA 10.78
# 12                                freedom    245xx         VA 10.08
# 13                          citicard fund    606xx         IL 12.56
# 14                             Other Loan    951xx         CA  7.06
# 15                Debt Consolidation Loan    641xx         MO 20.31
# 16                                   Home    921xx         CA 18.60
# 17                                Holiday    067xx         CT 10.52
# 18                                Medical    890xx         UT 18.44
# 19    lowerratemeanseasiertogetoutofdebt!    921xx         CA  9.86
# 20              Freedom From Credit Cards    770xx         TX 26.53
# 21                           Debt Cleanup    335xx         FL 13.22
# 22                       Credit Card Loan    799xx         TX 11.18
# 23                     Debt Consolidation    917xx         CA 16.01
# 24                                   cash    900xx         CA  2.40
# 25              No more credit card debt!    605xx         IL 29.44
# 26                          consolidation    103xx         NY 15.22
# 27                                  Other    150xx         PA 13.97
# 34                nan             nan                         nan
# 35                nan             nan                         nan
# 36                nan             nan                         nan
# 37                nan             nan                         nan
# 38                nan             nan                         nan
# 39                nan             nan                         nan
# 40                nan             nan                         nan
# 41                nan             nan                         nan
# 42                nan             nan                         nan
# 43                nan             nan                         nan
# 44                nan             nan                         nan
# 45                nan             nan                         nan
# 46                nan             nan                         nan
# 47                nan             nan                         nan
# 48                nan             nan                         nan
# 49                nan             nan                         nan
# 50                nan             nan                         nan
# 51                nan             nan                         nan
# 52                nan             nan                         nan
# 53                nan             nan                         nan
# 54                nan             nan                         nan
# 55                nan             nan                         nan
# 56                nan             nan                         nan
# 57                nan             nan                         nan
# 58                nan             nan                         nan
# 59                nan             nan                         nan
# 60                nan             nan                         nan
# 61                nan             nan                         nan
# 62                nan             nan                         nan
# 63                nan             nan                         nan
# 64                nan             nan                         nan
# 65                nan             nan                         nan
# 66                nan             nan                         nan
# 67                nan             nan                         nan
# 68                nan             nan                         nan
# 69                nan             nan                         nan
# 70                nan             nan                         nan
# 71                nan             nan                         nan
# 72                nan             nan                         nan
# 73                nan             nan                         nan
# 74                nan             nan                         nan
# 75                nan             nan                         nan
# 76                nan             nan                         nan
# 77                nan             nan                         nan
# 78                nan             nan                         nan
# 79                nan             nan                         nan
# 80                nan             nan                         nan
# 81                nan             nan                         nan
# 82                nan             nan                         nan
# 83                nan             nan                         nan
# 84                nan             nan                         nan
# 85                nan             nan                         nan
# 86                nan             nan                         nan
# 87                nan             nan                         nan
# 88                nan             nan                         nan
# 89                nan             nan                         nan
# 90                nan             nan                         nan
# 91                nan             nan                         nan
# 92                nan             nan                         nan
# 93                nan             nan                         nan
# 94                nan             nan                         nan
# 95                nan             nan                         nan
# 96                nan             nan                         nan
# 97                nan             nan                         nan
# 98                nan             nan                         nan
# 99                nan             nan                         nan

# %%
df['purpose'].value_counts()
# Out:
# debt_consolidation    18641
# credit_card            5130
# other                  3993
# home_improvement       2976
# major_purchase         2187
# small_business         1828
# car                    1549
# wedding                 947
# medical                 693
# moving                  583
# vacation                381
# house                   381
# educational             325
# renewable_energy        103
# Name: purpose, dtype: int64

# %% [markdown]
# # 2. Data Cleaning

# %% [markdown]
# ##### Observations on Variables
#
# 1) `term` is object, should be numeric.
#
# 2) `int_rate` is object , should be numeric
#
# 3) `emp_title` has Nan values , instead of nan, 'Unknown' can be imputed if necessary
#
# 4) `emp_length` has to be standardized, there is greater than symbol and years mentioned , this should be converted to numeric
#
# 5)`issue_d`, `earliest_cr_line` has to be converted to date field
#
# 6) `revol_util` has to be standardized , % symbol has to be removed, datatype should be numeric
#
# 7)NaN-`next_pymnt_d`,`collections_12_mths_ex_med`,`mths_since_last_major_derog`,`annual_inc_joint`,`dti_joint`,
# `verification_status_joint`,`tot_coll_amt`,`tot_cur_bal`,`open_acc_6m`,`open_il_6m`,`open_il_12m` etc
#
#
# All the records with more than 65% null/ nan will be removed

# %%
# id - A unique LC assigned ID for the loan listing.

len(df['id'].unique())
# Out:
# 39717

# %% [markdown]
# #### All records are unique based on the primary key

# %%
df.count()
# Out:
# id                                39717
# member_id                         39717
# loan_amnt                         39717
# funded_amnt                       39717
# funded_amnt_inv                   39717
# term                              39717
# int_rate                          39717
# installment                       39717
# grade                             39717
# sub_grade                         39717
# emp_title                         37258
# emp_length                        38642
# home_ownership                    39717
# annual_inc                        39717
# verification_status               39717
# issue_d                           39717
# loan_status                       39717
# pymnt_plan                        39717
# url                               39717
# desc                              26777
# purpose                           39717
# title                             39706
# zip_code                          39717
# addr_state                        39717
# dti                               39717
# delinq_2yrs                       39717
# earliest_cr_line                  39717
# inq_last_6mths                    39717
# mths_since_last_delinq            14035
# mths_since_last_record             2786
# open_acc                          39717
# pub_rec                           39717
# revol_bal                         39717
# revol_util                        39667
# total_acc                         39717
# initial_list_status               39717
# out_prncp                         39717
# out_prncp_inv                     39717
# total_pymnt                       39717
# total_pymnt_inv                   39717
# total_rec_prncp                   39717
# total_rec_int                     39717
# total_rec_late_fee                39717
# recoveries                        39717
# collection_recovery_fee           39717
# last_pymnt_d                      39646
# last_pymnt_amnt                   39717
# next_pymnt_d                       1140
# last_credit_pull_d                39715
# collections_12_mths_ex_med        39661
# mths_since_last_major_derog           0
# policy_code                       39717
# application_type                  39717
# annual_inc_joint                      0
# dti_joint                             0
# verification_status_joint             0
# acc_now_delinq                    39717
# tot_coll_amt                          0
# tot_cur_bal                           0
# open_acc_6m                           0
# open_il_6m                            0
# open_il_12m                           0
# open_il_24m                           0
# mths_since_rcnt_il                    0
# total_bal_il                          0
# il_util                               0
# open_rv_12m                           0
# open_rv_24m                           0
# max_bal_bc                            0
# all_util                              0
# total_rev_hi_lim                      0
# inq_fi                                0
# total_cu_tl                           0
# inq_last_12m                          0
# acc_open_past_24mths                  0
# avg_cur_bal                           0
# bc_open_to_buy                        0
# bc_util                               0
# chargeoff_within_12_mths          39661
# delinq_amnt                       39717
# mo_sin_old_il_acct                    0
# mo_sin_old_rev_tl_op                  0
# mo_sin_rcnt_rev_tl_op                 0
# mo_sin_rcnt_tl                        0
# mort_acc                              0
# mths_since_recent_bc                  0
# mths_since_recent_bc_dlq              0
# mths_since_recent_inq                 0
# mths_since_recent_revol_delinq        0
# num_accts_ever_120_pd                 0
# num_actv_bc_tl                        0
# num_actv_rev_tl                       0
# num_bc_sats                           0
# num_bc_tl                             0
# num_il_tl                             0
# num_op_rev_tl                         0
# num_rev_accts                         0
# num_rev_tl_bal_gt_0                   0
# num_sats                              0
# num_tl_120dpd_2m                      0
# num_tl_30dpd                          0
# num_tl_90g_dpd_24m                    0
# num_tl_op_past_12m                    0
# pct_tl_nvr_dlq                        0
# percent_bc_gt_75                      0
# pub_rec_bankruptcies              39020
# tax_liens                         39678
# tot_hi_cred_lim                       0
# total_bal_ex_mort                     0
# total_bc_limit                        0
# total_il_high_credit_limit            0
# dtype: int64

# %% [markdown]
# #### We can see there are a lot of variables with zero record count

# %%
df.describe()
# Out:
#               id  member_id  loan_amnt  funded_amnt  funded_amnt_inv  \
#
#        num_tl_30dpd  num_tl_90g_dpd_24m  num_tl_op_past_12m  pct_tl_nvr_dlq  \
# count          0.00                0.00                0.00            0.00
# mean            nan                 nan                 nan             nan
# std             nan                 nan                 nan             nan
# min             nan                 nan                 nan             nan
# 25%             nan                 nan                 nan             nan
# 50%             nan                 nan                 nan             nan
# 75%             nan                 nan                 nan             nan
# max             nan                 nan                 nan             nan
#
#        percent_bc_gt_75  pub_rec_bankruptcies  tax_liens  tot_hi_cred_lim  \
# count              0.00              39020.00   39678.00             0.00
# mean                nan                  0.04       0.00              nan
# std                 nan                  0.20       0.00              nan
# min                 nan                  0.00       0.00              nan
# 25%                 nan                  0.00       0.00              nan
# 50%                 nan                  0.00       0.00              nan
# 75%                 nan                  0.00       0.00              nan
# max                 nan                  2.00       0.00              nan
#
#        total_bal_ex_mort  total_bc_limit  total_il_high_credit_limit
# count               0.00            0.00                        0.00
# mean                 nan             nan                         nan
# std                  nan             nan                         nan
# min                  nan             nan                         nan
# 25%                  nan             nan                         nan
# 50%                  nan             nan                         nan
# 75%                  nan             nan                         nan
# max                  nan             nan                         nan

# %%
def missing_values_table(df):
        mis_val = df.isnull().sum()
        mis_val_percent = 100 * df.isnull().sum() / len(df)
        mis_val_table = pd.concat([mis_val, mis_val_percent], axis=1)
        mis_val_table_ren_columns = mis_val_table.rename(
        columns = {0 : 'Missing Values', 1 : '% of Total Values'})
        mis_val_table_ren_columns = mis_val_table_ren_columns[
            mis_val_table_ren_columns.iloc[:,1] != 0].sort_values(
        '% of Total Values', ascending=False).round(1)
        print ("There are " + str(mis_val_table_ren_columns.shape[0]) +
              " columns that have missing values.")
        return mis_val_table_ren_columns

# %%
missing_values_table(df)
# Out:
# There are 68 columns that have missing values.
#                                 Missing Values  % of Total Values
# bc_open_to_buy                           39717             100.00
# acc_open_past_24mths                     39717             100.00
# bc_util                                  39717             100.00
# mo_sin_old_il_acct                       39717             100.00
# mo_sin_old_rev_tl_op                     39717             100.00
# mo_sin_rcnt_rev_tl_op                    39717             100.00
# mo_sin_rcnt_tl                           39717             100.00
# mort_acc                                 39717             100.00
# mths_since_recent_bc                     39717             100.00
# mths_since_recent_bc_dlq                 39717             100.00
# mths_since_recent_inq                    39717             100.00
# mths_since_recent_revol_delinq           39717             100.00
# num_accts_ever_120_pd                    39717             100.00
# num_actv_bc_tl                           39717             100.00
# num_actv_rev_tl                          39717             100.00
# num_bc_sats                              39717             100.00
# num_bc_tl                                39717             100.00
# num_il_tl                                39717             100.00
# num_op_rev_tl                            39717             100.00
# num_rev_accts                            39717             100.00
# num_rev_tl_bal_gt_0                      39717             100.00
# num_sats                                 39717             100.00
# num_tl_120dpd_2m                         39717             100.00
# num_tl_30dpd                             39717             100.00
# num_tl_90g_dpd_24m                       39717             100.00
# num_tl_op_past_12m                       39717             100.00
# pct_tl_nvr_dlq                           39717             100.00
# percent_bc_gt_75                         39717             100.00
# tot_hi_cred_lim                          39717             100.00
# total_bal_ex_mort                        39717             100.00
# total_bc_limit                           39717             100.00
# avg_cur_bal                              39717             100.00
# total_il_high_credit_limit               39717             100.00
# inq_last_12m                             39717             100.00
# mths_since_rcnt_il                       39717             100.00
# mths_since_last_major_derog              39717             100.00
# annual_inc_joint                         39717             100.00
# dti_joint                                39717             100.00
# verification_status_joint                39717             100.00
# tot_coll_amt                             39717             100.00
# open_acc_6m                              39717             100.00
# open_il_6m                               39717             100.00
# open_il_12m                              39717             100.00
# open_il_24m                              39717             100.00
# tot_cur_bal                              39717             100.00
# total_bal_il                             39717             100.00
# open_rv_12m                              39717             100.00
# open_rv_24m                              39717             100.00
# max_bal_bc                               39717             100.00
# all_util                                 39717             100.00
# total_rev_hi_lim                         39717             100.00
# inq_fi                                   39717             100.00
# total_cu_tl                              39717             100.00
# il_util                                  39717             100.00
# next_pymnt_d                             38577              97.10
# mths_since_last_record                   36931              93.00
# mths_since_last_delinq                   25682              64.70
# desc                                     12940              32.60
# emp_title                                 2459               6.20
# emp_length                                1075               2.70
# pub_rec_bankruptcies                       697               1.80
# last_pymnt_d                                71               0.20
# chargeoff_within_12_mths                    56               0.10
# collections_12_mths_ex_med                  56               0.10
# revol_util                                  50               0.10
# tax_liens                                   39               0.10
# title                                       11               0.00
# last_credit_pull_d                           2               0.00

# %%
missing_df = missing_values_table(df);
missing_columns = list(missing_df[missing_df['% of Total Values'] > 60].index)
print('Remove %d columns.' % len(missing_columns))
# Out:
# There are 68 columns that have missing values.
# Remove 57 columns.

# %%
missing_columns
# Out:
# ['bc_open_to_buy',
#  'acc_open_past_24mths',
#  'bc_util',
#  'mo_sin_old_il_acct',
#  'mo_sin_old_rev_tl_op',
#  'mo_sin_rcnt_rev_tl_op',
#  'mo_sin_rcnt_tl',
#  'mort_acc',
#  'mths_since_recent_bc',
#  'mths_since_recent_bc_dlq',
#  'mths_since_recent_inq',
#  'mths_since_recent_revol_delinq',
#  'num_accts_ever_120_pd',
#  'num_actv_bc_tl',
#  'num_actv_rev_tl',
#  'num_bc_sats',
#  'num_bc_tl',
#  'num_il_tl',
#  'num_op_rev_tl',
#  'num_rev_accts',
#  'num_rev_tl_bal_gt_0',
#  'num_sats',
#  'num_tl_120dpd_2m',
#  'num_tl_30dpd',
#  'num_tl_90g_dpd_24m',
#  'num_tl_op_past_12m',
#  'pct_tl_nvr_dlq',
#  'percent_bc_gt_75',
#  'tot_hi_cred_lim',
#  'total_bal_ex_mort',
#  'total_bc_limit',
#  'avg_cur_bal',
#  'total_il_high_credit_limit',
#  'inq_last_12m',
#  'mths_since_rcnt_il',
#  'mths_since_last_major_derog',
#  'annual_inc_joint',
#  'dti_joint',
#  'verification_status_joint',
#  'tot_coll_amt',
#  'open_acc_6m',
#  'open_il_6m',
#  'open_il_12m',
#  'open_il_24m',
#  'tot_cur_bal',
#  'total_bal_il',
#  'open_rv_12m',
#  'open_rv_24m',
#  'max_bal_bc',
#  'all_util',
#  'total_rev_hi_lim',
#  'inq_fi',
#  'total_cu_tl',
#  'il_util',
#  'next_pymnt_d',
#  'mths_since_last_record',
#  'mths_since_last_delinq']

# %%
df = df.drop(columns = list(missing_columns))

# %%
df.replace('n/a', np.nan,inplace=True)

# Created new column term_month and converted object to integer
df['term_months'] = df['term'].str.extract('(\d+)').astype(int)

# Removing percentage sign and cconverting to float
df['int_rate']=list(map(lambda x: x[:-1], df['int_rate'].values))
df['int_rate'] = [float(x) for x in df['int_rate'].values]

# Converting NAN in emp_title to 'Unknown'
#df['emp_title'] = df.replace(np.NaN, 'Unknown', regex=True)

# Adding new column emp_length
# df.emp_length.fillna(value=0,inplace=True)
# df['emp_length'].replace(to_replace='[^0-9]+', value='', inplace=True, regex=True)
# df['emp_length'] = df['emp_length'].astype(int)

# Removing percentage sign and cconverting to float
df['revol_util'] = df['revol_util'].str.replace("%","").astype(float)

# Binning dti
df['dti_'] = pd.cut(df['dti'], [0,5,10,15,20,25,30], labels=['0-5','5-10','10-15','15-20','20-25','25-30'])

# %%
df.emp_length.value_counts()
# Out:
# 10+ years    8879
# < 1 year     4583
# 2 years      4388
# 3 years      4095
# 4 years      3436
# 5 years      3282
# 1 year       3240
# 6 years      2229
# 7 years      1773
# 8 years      1479
# 9 years      1258
# Name: emp_length, dtype: int64

# %% [markdown]
# Lets remove years from all records and convert it into float.
# * replace 10+ with 10 and <1 with 0 as per given instructions in data dictionary sheet.

# %%
length={'10+ years' : 10,
        '2 years' : 2,
        '< 1 year':0,
        '3 years':3,
        '4 years':4,
        '5 years':5,
        '1 year':1, 
        '6 years':6,
        '7 years':7,
        '8 years':8,
        '9 years':9}

# %%
df.emp_length=df.emp_length.replace(length).astype(float)

# %%
df.emp_length.value_counts()
# Out:
# 10.00    8879
# 0.00     4583
# 2.00     4388
# 3.00     4095
# 4.00     3436
# 5.00     3282
# 1.00     3240
# 6.00     2229
# 7.00     1773
# 8.00     1479
# 9.00     1258
# Name: emp_length, dtype: int64

# %%
#remove all missing value observations < 100
#Column--> last_pymnt_d,last_credit_pull_d,revol_util,title       
df=df.dropna(how='any',subset=['last_pymnt_d','last_credit_pull_d','revol_util','title'])

# %%
# Correcting all the date fields

df['issue_d'] = pd.to_datetime(df['issue_d'], format='%b-%y')
df['earliest_cr_line'] = pd.to_datetime(df['earliest_cr_line'], format='%b-%y')
df['last_pymnt_d'] = pd.to_datetime(df['last_pymnt_d'], format='%b-%y')
df['last_credit_pull_d'] = pd.to_datetime(df['last_credit_pull_d'], format='%b-%y')

# %%
df[['issue_d','earliest_cr_line','last_pymnt_d','last_credit_pull_d']].head()
# Out:
#      issue_d earliest_cr_line last_pymnt_d last_credit_pull_d
# 0 2011-12-01       1985-01-01   2015-01-01         2016-05-01
# 1 2011-12-01       1999-04-01   2013-04-01         2013-09-01
# 2 2011-12-01       2001-11-01   2014-06-01         2016-05-01
# 3 2011-12-01       1996-02-01   2015-01-01         2016-04-01
# 4 2011-12-01       1996-01-01   2016-05-01         2016-05-01

# %%
sns.countplot(df['loan_status'])
plt.xticks(
    fontweight='light',
    fontsize='x-large'  
)
df['loan_status'].value_counts()
# Out:
# Fully Paid     32906
# Charged Off     5541
# Current         1140
# Name: loan_status, dtype: int64

# %%
# Filtering data with only Fully Paid and Charged Off as current representing the loan still running

df = df[df['loan_status'].isin(['Fully Paid','Charged Off'])]

# %%
#percentage of defaulter customers 
print("%.2f" % (df.loc[df['loan_status'] == 'Charged Off'].loan_status.count() * 100/len(df)))
# Out:
# 14.41

# %%
df['loan_status'] = df['loan_status'].astype('category')
df['loan_status'].value_counts()
# Out:
# Fully Paid     32906
# Charged Off     5541
# Name: loan_status, dtype: int64

# %%
# filtering only fully paid or charged-off
df = df[df['loan_status'] != 'Current']
#df['loan_status'] = df['loan_status'].apply(lambda x: 0 if x=='Fully Paid' else 1)

# converting loan_status to integer type
#df['loan_status'] = df['loan_status'].apply(lambda x: pd.to_numeric(x))

# summarising the values
df['loan_status'].value_counts()
# Out:
# Fully Paid     32906
# Charged Off     5541
# Name: loan_status, dtype: int64

# %% [markdown]
# ### There are 14.5 % loan defaulters

# %% [markdown]
# ###  `'loan_status' will be the target variable `

# %%
df.describe()
# Out:
#               id  member_id  loan_amnt  funded_amnt  funded_amnt_inv  \
# count   38447.00   38447.00   38447.00     38447.00         38447.00
# mean   676619.72  842595.79   11060.43     10796.80         10237.36
# std    209262.71  264419.84    7346.94      7088.63          7022.76
# min     54734.00   70699.00     500.00       500.00             0.00
# 25%    512299.00  661398.50    5375.00      5200.00          5000.00
# 50%    656937.00  839559.00    9700.00      9600.00          8758.61
# 75%    829340.00 1037577.50   15000.00     15000.00         14000.00
# max   1077501.00 1314167.00   35000.00     35000.00         35000.00
#
#        int_rate  installment  emp_length  annual_inc      dti  delinq_2yrs  \
# count  38447.00     38447.00    37423.00    38447.00 38447.00     38447.00
# mean      11.92       322.82        4.94    68849.72    13.28         0.15
# std        3.69       208.61        3.56    64263.45     6.67         0.49
# min        5.42        15.69        0.00     4000.00     0.00         0.00
# 25%        8.94       165.82        2.00    40000.00     8.14         0.00
# 50%       11.71       278.25        4.00    59000.00    13.37         0.00
# 75%       14.35       426.10        9.00    82000.00    18.56         0.00
# max       24.40      1305.19       10.00  6000000.00    29.99        11.00
#
#        inq_last_6mths  open_acc  pub_rec  revol_bal  revol_util  total_acc  \
# count        38447.00  38447.00 38447.00   38447.00    38447.00   38447.00
# mean             0.87      9.28     0.06   13319.14       48.70      22.08
# std              1.07      4.40     0.24   15878.18       28.36      11.42
# min              0.00      2.00     0.00       0.00        0.00       2.00
# 25%              0.00      6.00     0.00    3675.50       25.20      13.00
# 50%              1.00      9.00     0.00    8788.00       49.10      20.00
# 75%              1.00     12.00     0.00   16947.00       72.30      29.00
# max              8.00     44.00     4.00  149588.00       99.90      90.00
#
#        out_prncp  out_prncp_inv  total_pymnt  total_pymnt_inv  \
# count   38447.00       38447.00     38447.00         38447.00
# mean        0.00           0.00     11897.53         11301.03
# std         0.00           0.00      8805.29          8697.06
# min         0.00           0.00        33.73             0.00
# 25%         0.00           0.00      5537.42          5046.00
# 50%         0.00           0.00      9706.20          9098.16
# 75%         0.00           0.00     16158.72         15366.85
# max         0.00           0.00     58563.68         58563.68
#
#        total_rec_prncp  total_rec_int  total_rec_late_fee  recoveries  \
# count         38447.00       38447.00            38447.00    38447.00
# mean           9674.46        2124.57                1.37       97.12
# std            7004.06        2390.79                7.33      695.87
# min               0.00           6.22                0.00        0.00
# 25%            4500.00         647.15                0.00        0.00
# 50%            8000.00        1304.18                0.00        0.00
# 75%           13200.00        2676.42                0.00        0.00
# max           35000.02       23563.68              180.20    29623.35
#
#        collection_recovery_fee  last_pymnt_amnt  collections_12_mths_ex_med  \
# count                 38447.00         38447.00                    38391.00
# mean                     12.66          2754.71                        0.00
# std                     150.59          4499.71                        0.00
# min                       0.00             0.00                        0.00
# 25%                       0.00           218.97                        0.00
# 50%                       0.00           572.32                        0.00
# 75%                       0.00          3463.69                        0.00
# max                    7002.19         36115.20                        0.00
#
#        policy_code  acc_now_delinq  chargeoff_within_12_mths  delinq_amnt  \
# count     38447.00        38447.00                  38391.00     38447.00
# mean          1.00            0.00                      0.00         0.00
# std           0.00            0.00                      0.00         0.00
# min           1.00            0.00                      0.00         0.00
# 25%           1.00            0.00                      0.00         0.00
# 50%           1.00            0.00                      0.00         0.00
# 75%           1.00            0.00                      0.00         0.00
# max           1.00            0.00                      0.00         0.00
#
#        pub_rec_bankruptcies  tax_liens  term_months
# count              37751.00   38408.00     38447.00
# mean                   0.04       0.00        41.90
# std                    0.20       0.00        10.34
# min                    0.00       0.00        36.00
# 25%                    0.00       0.00        36.00
# 50%                    0.00       0.00        36.00
# 75%                    0.00       0.00        36.00
# max                    2.00       0.00        60.00

# %% [markdown]
# #### Column Analysis

# %% [markdown]
# `id` or `member_id` as it has no real predictive power since those are primary and unique key columns

# %%
# Dropping unwanted columns 

df=df.drop(['id','member_id'], axis = 1)

# %%
df.shape
# Out:
# (38447, 54)

# %%
df.columns.tolist
# Out:
# <bound method IndexOpsMixin.tolist of Index(['loan_amnt', 'funded_amnt', 'funded_amnt_inv', 'term', 'int_rate',
#        'installment', 'grade', 'sub_grade', 'emp_title', 'emp_length',
#        'home_ownership', 'annual_inc', 'verification_status', 'issue_d',
#        'loan_status', 'pymnt_plan', 'url', 'desc', 'purpose', 'title',
#        'zip_code', 'addr_state', 'dti', 'delinq_2yrs', 'earliest_cr_line',
#        'inq_last_6mths', 'open_acc', 'pub_rec', 'revol_bal', 'revol_util',
#        'total_acc', 'initial_list_status', 'out_prncp', 'out_prncp_inv',
#        'total_pymnt', 'total_pymnt_inv', 'total_rec_prncp', 'total_rec_int',
#        'total_rec_late_fee', 'recoveries', 'collection_recovery_fee',
#        'last_pymnt_d', 'last_pymnt_amnt', 'last_credit_pull_d',
#        'collections_12_mths_ex_med', 'policy_code', 'application_type',
#        'acc_now_delinq', 'chargeoff_within_12_mths', 'delinq_amnt',
#        'pub_rec_bankruptcies', 'tax_liens', 'term_months', 'dti_'],
#       dtype='object')>

# %% [markdown]
# #### Lets remove below variables which are not usful in analysis
# 1- `'acc_now_delinq'` All records are 0.
#
# 2- `'application_type'` All records are 'Individual' thats why not good to keep.
#
# 3- `'chargeoff_within_12_mths'` All records are 0.
#
# 4- `'collections_12_mths_ex_med'`All records are 0.
#
# 5- `'delinq_amnt'`All records are 0.
#
# 6- `'desc'`No value in analysis as same and information in short is available in other columns
#
# 7- `'zip_code'`Only first three digits are visible so not useful.
#
# 8- `'url'`This variable is not useful here in EDA.
#
# 9- `'tax_liens'`All records are 0.
#
# 10-` 'initial_list_status'`All records are 'f' so need to remove.
#
# 11-` 'policy_code'`All records are 1.
#
# 12-` 'pymnt_plan'`All records are 'n'.

# %%
drop=['acc_now_delinq'
,'application_type'
,'chargeoff_within_12_mths'
,'collections_12_mths_ex_med'
,'delinq_amnt'
,'desc'
,'zip_code'
,'url'
,'tax_liens'
,'initial_list_status'
,'policy_code'
,'pymnt_plan']
df=df.drop(labels=drop,axis=1)

# %%
missing=100*df.isnull().sum()/len(df)
missing[missing>0]
# Out:
# emp_title              6.17
# emp_length             2.66
# pub_rec_bankruptcies   1.81
# dti_                   0.44
# dtype: float64

# %%
#Lets remove all observatins with missing value from all these variables
df=df.dropna(how='any',subset=['emp_title','emp_length','pub_rec_bankruptcies','dti_'])

# %%
#Lets check the uniques records for all variables.
df.nunique().sort_values()
# Out:
# out_prncp                      1
# out_prncp_inv                  1
# term_months                    2
# term                           2
# loan_status                    2
# pub_rec_bankruptcies           3
# verification_status            3
# home_ownership                 4
# pub_rec                        5
# dti_                           6
# grade                          7
# inq_last_6mths                 9
# delinq_2yrs                   11
# emp_length                    11
# purpose                       14
# sub_grade                     35
# open_acc                      38
# addr_state                    49
# issue_d                       52
# total_acc                     79
# last_credit_pull_d            96
# last_pymnt_d                  97
# int_rate                     334
# earliest_cr_line             508
# loan_amnt                    847
# funded_amnt                 1001
# revol_util                  1081
# total_rec_late_fee          1156
# collection_recovery_fee     2378
# dti                         2841
# recoveries                  3566
# annual_inc                  4811
# total_rec_prncp             6170
# funded_amnt_inv             7302
# installment                13995
# title                      17591
# revol_bal                  20347
# emp_title                  27322
# total_rec_int              31364
# last_pymnt_amnt            31870
# total_pymnt_inv            33344
# total_pymnt                33613
# dtype: int64

# %%
#out_prncp and out_prncp_inv are having only one unique value. Lets check what is that.
df[['out_prncp','out_prncp_inv']].describe()
# Out:
#        out_prncp  out_prncp_inv
# count   35227.00       35227.00
# mean        0.00           0.00
# std         0.00           0.00
# min         0.00           0.00
# 25%         0.00           0.00
# 50%         0.00           0.00
# 75%         0.00           0.00
# max         0.00           0.00

# %%
#both variables have only 0 so can be removed.
df=df.drop(labels=['out_prncp','out_prncp_inv'],axis=1)

# %%
df.shape
# Out:
# (35227, 40)

# %%
def multicatogory(df, arr):
    rows = int(len(arr)/2)
    for idx, val in enumerate(arr, start=1):
        plt.subplot(rows, 2, idx)
        ax = df.groupby(val).loan_amnt.count().plot.bar(color=sns.color_palette("coolwarm", 7))
        sns.despine(left=True, bottom=True)
    plt.tight_layout()

# %%
def p_percent(dataframe, by, sortbyindex=False):
    plt.subplot(1, 2, 1)
    values = (df[by].value_counts(normalize=True)*100)
    if sortbyindex:
        values = values.sort_index()
    ax = values.plot.bar(color=sns.color_palette("coolwarm", 7))
    ax.set_ylabel('Percentage in dataset', fontsize=16)
    ax.set_xlabel(by, fontsize=12)
    plt.subplot(1, 2, 2)
    values = (df.loc[df['loan_status']=='Charged Off'][by].value_counts(normalize=True)*100)
    if sortbyindex:
        values = values.sort_index()
    ax = values.plot.bar(color=sns.color_palette("coolwarm", 7))
    ax.set_ylabel('Percentage of Default loans', fontsize=16)
    sns.despine(left=True, bottom=True)

# %%
def pltloan(dataframe, by, loanstatus='Charged Off'):
    grp = dataframe.groupby(['loan_status',by])[by].count()
    cnt = dataframe.groupby(by)[by].count()
    percentages = grp.unstack() * 100 / cnt.T
    ax = percentages.loc[loanstatus].plot.bar(color=sns.color_palette("coolwarm", 7))
    ax.set_ylabel('Percentage of loans ' + loanstatus)
    plt.margins(0.2, 0.2)
    sns.despine(left=True, bottom=True)
    plt.tight_layout()
    return ax

# %%
def plot_dist(df, col):
    plt.figure(figsize=(15,5))
    plt.subplot(1, 2, 2)
    ax = sns.distplot(df[col])
    plt.subplot(1, 2, 1)
    sns.boxplot(y=df[col], x=df['loan_status'], data=df)
    plt.show()

# %% [markdown]
# # 3. EDA:Exploratory Data Analysis :
#
# The purpose is to find anomalies, patterns, trends, or relationships.

# %% [markdown]
# # Loan Amount Requested Versus the Funded Amount

# %%
# Analysis of the loan applied , amount funded and Total commited 

figsize(sizex=10,sizey=15)
cols_review = ['loan_amnt', 'funded_amnt', 'funded_amnt_inv']
fig, ax = plt.subplots(nrows=3)
sns.distplot(df["loan_amnt"].values, ax=ax[0])
ax[0].set_title("Loan Applied by Borrower", fontsize=14)
sns.distplot(df["funded_amnt"].values, ax=ax[1], color="blue")
ax[1].set_title("Amount Funded by Lender", fontsize=14)
sns.distplot(df["funded_amnt_inv"].values, ax=ax[2], color="green")
ax[2].set_title("Committed by Investors", fontsize=14)
plt.tight_layout()    
sns.despine(left=True, bottom=True)
plt.show()

# %%
(df.loan_amnt != df.funded_amnt).value_counts()
# Out:
# False    33589
# True      1638
# dtype: int64

# %% [markdown]
# #### "The listed amount of the loan applied for by the borrower. If at some point in time, the credit department reduces the loan amount, then it will be reflected in this value.” As per this comment we can see that the data can be manipulated hence we can ignore this comparison and  no insights can be derived

# %%
# Analysis on Interest Rates

df['int_rate'].describe()
# Out:
# count   35227.00
# mean       11.99
# std         3.70
# min         5.42
# 25%         8.94
# 50%        11.86
# 75%        14.50
# max        24.40
# Name: int_rate, dtype: float64

# %%
pd.set_option('display.max_rows',200)

# %%
figsize(sizex=10,sizey=7)
np.unique(df['int_rate'].values), pd.Series(df['int_rate'].values).plot(kind='hist',alpha=.7, bins=20, title='Interest Rate Distribution')
sns.despine(left=True, bottom=True)
plt.show()

# %%
sns.boxplot(x=df.term,y=df.int_rate)
sns.despine(left=True, bottom=True)
plt.show()

# %%
sns.boxplot(x=df.loan_status,y=df.int_rate)
plt.show()

# %%
df.groupby('loan_status')['int_rate'].describe()
# Out:
#                count  mean  std  min   25%   50%   75%   max
# loan_status
# Charged Off  4920.00 13.93 3.65 5.42 11.49 13.79 16.45 24.40
# Fully Paid  30307.00 11.67 3.62 5.42  8.59 11.49 14.09 24.11

# %% [markdown]
# - Bigger the loan, interset is high and longer period
# - Charged off cutomers had more interest rate as compared to Fully paid cutomers. It is obvious if risk is high, interest rate will also be higher for those customers.
# - Average Interest rate for charged off cutomers is 19% higher than fully paid customers.

# %%
df.describe()
# Out:
#        loan_amnt  funded_amnt  funded_amnt_inv  int_rate  installment  \
# count   35227.00     35227.00         35227.00  35227.00     35227.00
# mean    11146.79     10879.73         10440.38     11.99       324.42
# std      7330.48      7073.82          6972.01      3.70       207.30
# min       500.00       500.00             0.00      5.42        16.08
# 25%      5500.00      5500.00          5000.00      8.94       168.09
# 50%     10000.00      9600.00          9000.00     11.86       280.97
# 75%     15000.00     15000.00         14329.27     14.50       427.72
# max     35000.00     35000.00         35000.00     24.40      1305.19
#
#        emp_length  annual_inc      dti  delinq_2yrs  inq_last_6mths  open_acc  \
# count    35227.00    35227.00 35227.00     35227.00        35227.00  35227.00
# mean         4.98    69110.60    13.46         0.15            0.87      9.35
# std          3.54    63582.37     6.60         0.49            1.06      4.37
# min          0.00     4000.00     0.01         0.00            0.00      2.00
# 25%          2.00    41600.00     8.38         0.00            0.00      6.00
# 50%          4.00    60000.00    13.54         0.00            1.00      9.00
# 75%          9.00    82500.00    18.67         0.00            1.00     12.00
# max         10.00  6000000.00    29.99        11.00            8.00     44.00
#
#        pub_rec  revol_bal  revol_util  total_acc  total_pymnt  \
# count 35227.00   35227.00    35227.00   35227.00     35227.00
# mean      0.05   13418.53       49.33      22.24     12035.46
# std       0.24   15688.14       28.12      11.40      8822.65
# min       0.00       0.00        0.00       2.00        33.73
# 25%       0.00    3832.00       26.20      14.00      5611.89
# 50%       0.00    8978.00       49.80      21.00      9881.47
# 75%       0.00   17101.00       72.70      29.00     16325.81
# max       4.00  149588.00       99.90      90.00     58563.68
#
#        total_pymnt_inv  total_rec_prncp  total_rec_int  total_rec_late_fee  \
# count         35227.00         35227.00       35227.00            35227.00
# mean          11559.68          9777.54        2160.73                1.30
# std            8676.68          7002.96        2412.94                7.08
# min               0.00             0.00           6.22                0.00
# 25%            5333.58          4750.00         663.37                0.00
# 50%            9408.08          8000.00        1334.74                0.00
# 75%           15646.32         13500.00        2731.24                0.00
# max           58563.68         35000.02       23563.68              180.20
#
#        recoveries  collection_recovery_fee  last_pymnt_amnt  \
# count    35227.00                 35227.00         35227.00
# mean        95.88                    12.06          2817.84
# std        693.36                   143.25          4525.73
# min          0.00                     0.00             0.01
# 25%          0.00                     0.00           225.26
# 50%          0.00                     0.00           604.57
# 75%          0.00                     0.00          3613.28
# max      29623.35                  7002.19         36115.20
#
#        pub_rec_bankruptcies  term_months
# count              35227.00     35227.00
# mean                   0.04        42.11
# std                    0.20        10.46
# min                    0.00        36.00
# 25%                    0.00        36.00
# 50%                    0.00        36.00
# 75%                    0.00        60.00
# max                    2.00        60.00

# %%
# Converting issued date to years
ser = pd.to_datetime(df['issue_d'])
df['year'] = ser.dt.year

# %%
plt.figure(figsize=(10,6))
sns.set(style="whitegrid")
sns.barplot('year', 'loan_amnt', data=df)
plt.title('Issuance of Loans', fontsize=16)
plt.xlabel('Year', fontsize=14)
plt.ylabel('Average loan amount issued', fontsize=14)
plt.xticks(
    fontweight='light',
    fontsize='x-large'  
)
sns.despine(left=True, bottom=True)
plt.show()

# %% [markdown]
# #### The year of 2011 was the year were the highest amount of loans were issued

# %% [markdown]
# # Purpose and Title

# %%
print(df.purpose.value_counts())
print('')
print(df.title.value_counts().tail())
# Out:
# debt_consolidation    16891
# credit_card            4620
# other                  3437
# home_improvement       2591
# major_purchase         1951
# car                    1383
# small_business         1341
# wedding                 860
# medical                 622
# moving                  519
# vacation                331
# house                   324
# educational             272
# renewable_energy         85
# Name: purpose, dtype: int64
#
# Pay loans off         1
# Home Purchase Loan    1
# Closing Costs         1
# New Deal              1
# New Basement          1
# Name: title, dtype: int64

# %% [markdown]
#     debt_consolidation    18012
#     credit_card            5021
#     other                  3841
#     home_improvement       2867
#     major_purchase         2138
#     small_business         1742
#     car                    1497
#     wedding                 919
#     medical                 679
#     moving                  574
#     vacation                374
#     house                   365
#     educational             317
#     renewable_energy        101

# %%
# title is arbitrary free-text from the applicant we can drop this column
df.drop(['title' ],1, inplace=True)

# %% [markdown]
# # Employement Title

# %%
print(df.emp_title.value_counts())
df.emp_title.unique().shape
# Out:
# US Army                                       127
# Bank of America                               106
# IBM                                            65
# AT&T                                           57
# Kaiser Permanente                              55
#                                              ...
# Federal Emergency Management Agency (FEMA)      1
# pa department of corrections                    1
# Roxbury Board of Education                      1
# SKF USA                                         1
# TriSept Corporation                             1
# Name: emp_title, Length: 27322, dtype: int64
# (27322,)

# %% [markdown]
# #### 27322 unique employee titles. Data won’t be meaningful and any relationship we might observe might be due to confounding relationships. A more advanced implementation might look to group all these job descriptions into categories and/or examine if Lending Club’s model looks at (income + job) versus just income

# %% [markdown]
# # Employment Length

# %%
df['emp_length'].value_counts().sort_index()
# Out:
# 0.00     3960
# 1.00     2947
# 2.00     4069
# 3.00     3815
# 4.00     3191
# 5.00     3035
# 6.00     2051
# 7.00     1633
# 8.00     1356
# 9.00     1170
# 10.00    8000
# Name: emp_length, dtype: int64

# %%
df.loan_status
# Out:
# 1        Charged Off
# 3         Fully Paid
# 5         Fully Paid
# 6         Fully Paid
# 7         Fully Paid
#             ...
# 39551     Fully Paid
# 39562     Fully Paid
# 39623    Charged Off
# 39666    Charged Off
# 39680     Fully Paid
# Name: loan_status, Length: 35227, dtype: category
# Categories (2, object): [Charged Off, Fully Paid]

# %%
a=df.emp_length.value_counts().sort_index().keys()
b=df.emp_length.value_counts().sort_index().values
sns.barplot(data=df,x=df.emp_length,y=df.loan_amnt,estimator=np.mean)
plt.show()

# %% [markdown]
# - mean loan amount is slightly increaing over the working experience of customers

# %% [markdown]
# # Verification

# %%
df['verification_status'].value_counts()
# Out:
# Not Verified       14769
# Verified           11323
# Source Verified     9135
# Name: verification_status, dtype: int64

# %% [markdown]
# # Delinquency

# %%
# Distribution of delinquency across all applicants

df['delinq_2yrs'].value_counts()
# Out:
# 0     31415
# 1      2925
# 2       608
# 3       189
# 4        51
# 5        21
# 6        10
# 7         4
# 8         2
# 11        1
# 9         1
# Name: delinq_2yrs, dtype: int64

# %% [markdown]
# # Bivariate Analysis

# %% [markdown]
# ### loan_status will be the target variable and we will be comparing loan_status acorsss all catogorical variables

# %%
# Defining function for bivariate analysis with target variable

def bar_plt(obj):
    sns.barplot(x=obj, y='loan_status', data=df)
    plt.show()

# %%
# Finding catogorical variables

object_df = df.select_dtypes(include=['object'])
object_df
# Out:
#              term grade sub_grade                  emp_title home_ownership  \
# 1       60 months     C        C4                      Ryder           RENT
# 3       36 months     C        C1        AIR RESOURCES BOARD           RENT
# 5       36 months     A        A4       Veolia Transportaton           RENT
# 6       60 months     C        C5  Southern Star Photography           RENT
# 7       36 months     E        E1            MKC Accounting            RENT
# ...           ...   ...       ...                        ...            ...
# 39551   36 months     C        C3          Fullmoon Software           RENT
# 39562   36 months     C        C1              E.E. Wine Inc           RENT
# 39623   36 months     D        D3                    Maximus       MORTGAGE
# 39666   36 months     C        C4                       ARIN       MORTGAGE
# 39680   36 months     D        D1    Fairfield Manufacturing       MORTGAGE
#
#       verification_status             purpose addr_state
# 1         Source Verified                 car         GA
# 3         Source Verified               other         CA
# 5         Source Verified             wedding         AZ
# 6            Not Verified  debt_consolidation         NC
# 7         Source Verified                 car         CA
# ...                   ...                 ...        ...
# 39551        Not Verified  debt_consolidation         VA
# 39562        Not Verified  debt_consolidation         VA
# 39623        Not Verified  debt_consolidation         MD
# 39666        Not Verified  debt_consolidation         VA
# 39680        Not Verified  debt_consolidation         IN
#
# [35227 rows x 8 columns]

# %% [markdown]
# # Understanding Grade and comparison with Loan Amount based on term

# %%
(df['grade'].value_counts(normalize=True)*100).sort_index()
# Out:
# A   25.81
# B   30.29
# C   20.33
# D   13.19
# E    7.02
# F    2.56
# G    0.80
# Name: grade, dtype: float64

# %%
sns.barplot(x='grade', y='loan_amnt', hue="term", data=df, estimator=np.mean)
plt.xticks(
    fontweight='light',
    fontsize='x-large'  
)
sns.despine(left=True, bottom=True)
plt.show()

# %% [markdown]
# ###  Lower Grades are given larger loans - G,F,E grades

# %%
df.boxplot(column='loan_amnt', by='grade')
sns.despine(left=True, bottom=True)
plt.show()

# %% [markdown]
# ### The median loan amount for a grade G is higher than that of a grade A, B, or C loan. Almost 1050 more

# %%
# Comparing Sub Grade 
plt.figure(figsize=(16, 6))
sns.barplot(x='sub_grade', y='loan_amnt', hue="term", data=df, estimator=np.mean)
sns.despine(left=True, bottom=True)
plt.show()

# %%
df.boxplot(column='int_rate', by='sub_grade',figsize=(16,6))
sns.despine(left=True, bottom=True)
plt.show()

# %% [markdown]
# ### Lower the grades higher the interest rate. This is a deciding factor

# %%
#comparint term
sns.boxplot(x=df.term,y=df.loan_amnt)
sns.despine(left=True, bottom=True)
plt.show()

# %% [markdown]
# Loan amount for high period is high and low for lower period.

# %%
# Comparing term 

sns.barplot(x='term', y='loan_amnt', hue="loan_status", data=df, estimator=np.mean)
sns.despine(left=True, bottom=True)
plt.show()

# %%
#df.boxplot(column='int_rate', by='loan_status',figsize=(7,5))
sns.boxplot(x=df.loan_status,y=df.int_rate)
sns.despine(left=True, bottom=True)
plt.show()

# %% [markdown]
# Customers who charged off are having high interest rate as compared to others.

# %%
# Comparing home ownership 

sns.barplot(x='home_ownership', y='loan_amnt', hue="loan_status", data=df)
sns.despine(left=True, bottom=True)
plt.show()

# %% [markdown]
# Customers with Mortgage type of home ownership had highest amount of loan

# %%
# Comparing verification status

sns.barplot(x='verification_status', y='loan_amnt', hue="loan_status", data=df, estimator=np.mean)
sns.despine(left=True, bottom=True)
plt.show()

# %% [markdown]
# - Higher amount of loans are verifed which is obvious as loan with higher amount is more risky. Likewise less amount of loans are not verified.

# %%
# Comparing Loan Amount with Purpose 

plt.figure(figsize=(24, 9))
sns.barplot(x='purpose', y='loan_amnt', hue="loan_status", data=df, estimator=len)
plt.xticks(
    rotation=45, 
    horizontalalignment='right',
    fontweight='light',
    fontsize='x-large'  
)
sns.despine(left=True, bottom=True)
plt.show()

# %% [markdown]
#   - Higher number of loan has been taken for debt_consolidation
#   - Highest amount of loan has been taken for business pupose.

# %%
# Comparing Loan Amount with Purpose 

plt.figure(figsize=(18, 6))
sns.barplot(x='purpose', y='loan_amnt', hue="loan_status", data=df)
sns.despine(left=True, bottom=True)
plt.show()

# %%
# Comparing Loan Amount with Year
plt.figure(figsize=(12, 6))
sns.barplot(x='year', y='loan_amnt', data=df, estimator=np.mean)
sns.despine(left=True, bottom=True)
plt.show()

# %%
plt.figure(figsize=(12, 6))
sns.barplot(x='year', y='loan_amnt', data=df, estimator=len)
sns.despine(left=True, bottom=True)
plt.show()

# %% [markdown]
# - Overall mean loan amount and count of loan issued are increasing over the years.

# %%
#sns.jointplot('annual_inc','loan_amnt',df.loc[df['annual_inc']<100000])
sns.scatterplot('annual_inc', 'loan_amnt',data=df.loc[df['annual_inc']<100000], hue=df.loan_status)
#sns.scatterplot('annual_inc', 'loan_amnt',data=df, hue=df.loan_status)
sns.despine(left=True, bottom=True)
plt.show()

# %% [markdown]
# ### People with annual income less than  100,000 is taking loan up to 35000 which is risky
# ### In second plot, it is observed that frequency of defaulters is less  who have good salary.

# %%
sns.scatterplot('annual_inc', 'loan_amnt', data = df.loc[(df['annual_inc']>100000) & (df['annual_inc']<2000000)],hue=df.loan_status)
sns.despine(left=True, bottom=True)
plt.show()

# %%
df.loc[df['annual_inc']<260000].boxplot(column='annual_inc', by='grade')
sns.despine(left=True, bottom=True)
plt.show()

# %%
plt.figure(figsize=(15,5))
p_percent(df,'purpose')

# %%
# Comparing DTI with Open Creditline 

plt.figure(figsize=(20,5))
sns.barplot(x='dti_', y='open_acc', hue='loan_status',data=df, estimator=np.mean)
sns.despine(left=True, bottom=True)
plt.show()

# %% [markdown]
# ### Dti increses with the number of open account

# %%
# delinq_2yr VS loan amount VS grade¶

plt.figure(figsize=(20,5))
sns.barplot(x='delinq_2yrs', y='loan_amnt', hue='grade',data=df, estimator=np.mean)
sns.despine(left=True, bottom=True)
plt.show()

# %%
multicatogory(df, ['home_ownership', 'term'])

# %% [markdown]
# #### Most of the loans where taken by customers who hass a morgage or who lives in rent
# #### Higher number of loans where given for shorter term

# %%
multicatogory(df, ['grade', 'pub_rec_bankruptcies'])

# %%
plt.figure(figsize=(10,5))
p_percent(df, 'term')

# %% [markdown]
# #### Default loans, 60 months term rises to 45%.
# #### Higher term loans have a higher chance of default.

# %% [markdown]
# ###  People having two or more delinquencies has loan amounts greater than 15000 on average.

# %%
corr=df.corr()
corr['loan_amnt']
# Out:
# loan_amnt                  1.00
# funded_amnt                0.98
# funded_amnt_inv            0.95
# int_rate                   0.30
# installment                0.93
# emp_length                 0.14
# annual_inc                 0.26
# dti                        0.06
# delinq_2yrs               -0.03
# inq_last_6mths             0.01
# open_acc                   0.17
# pub_rec                   -0.05
# revol_bal                  0.32
# revol_util                 0.06
# total_acc                  0.25
# total_pymnt                0.88
# total_pymnt_inv            0.86
# total_rec_prncp            0.85
# total_rec_int              0.73
# total_rec_late_fee         0.05
# recoveries                 0.14
# collection_recovery_fee    0.08
# last_pymnt_amnt            0.48
# pub_rec_bankruptcies      -0.03
# term_months                0.35
# year                       0.12
# Name: loan_amnt, dtype: float64

# %%
plt.figure(figsize=(20,20))
variables= ['loan_amnt', 'int_rate', 'installment',
       'emp_length', 'annual_inc',
       'dti', 'delinq_2yrs', 'earliest_cr_line',
       'inq_last_6mths', 'open_acc', 'pub_rec', 'revol_bal', 'revol_util',
       'total_acc', 'last_pymnt_d', 'last_pymnt_amnt', 'last_credit_pull_d',
       'pub_rec_bankruptcies']
corr = df[variables].corr()
sns.despine(left=True, bottom=True)
sns.heatmap(corr, annot=True, center=0.5)
plt.show()

# %% [markdown]
#     Loan_amnt is correlated to last_payment_amount -.47
#     Interest rate is correlated to revol_util- .47
#     delinq_2yrs is non correlated with public record of bankruptcy.

# %%
plt.figure(figsize=(10, 5))
pltloan(df, 'purpose')

# %% [markdown]
# #### Small business shows a bigger risk

# %%
df[['pub_rec', 'pub_rec_bankruptcies']].corr()
# Out:
#                       pub_rec  pub_rec_bankruptcies
# pub_rec                  1.00                  0.84
# pub_rec_bankruptcies     0.84                  1.00

# %%
plot_dist(df,'dti')

# %%
df1=(df.loc[df.loan_status=='Charged Off',['dti_','loan_status']])
df2=(df.loc[::,['dti_','loan_status']])
d=pd.concat([df1.groupby('dti_')['loan_status'].count(),df2.groupby('dti_')['loan_status'].count()],axis=1)
d['dti']=d.index
d.columns=['Charged Off','Total','dti']
d['Charged Off %']=100*d['Charged Off']/d.Total

# %%
d
# Out:
#        Charged Off  Total    dti  Charged Off %
# dti_
# 0-5            496   4292    0-5          11.56
# 5-10           848   7125   5-10          11.90
# 10-15         1260   8901  10-15          14.16
# 15-20         1235   8170  15-20          15.12
# 20-25         1003   6164  20-25          16.27
# 25-30           78    575  25-30          13.57

# %%
sns.barplot(x=d.dti,y=d['Charged Off %'])
plt.show()

# %% [markdown]
# ### Charged Off customer percentage is increasing with increase of debt to income ratio
